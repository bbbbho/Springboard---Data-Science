# %% [markdown]
# # XML example and exercise
# ****
# + study examples of accessing nodes in XML tree structure
# + work on exercise to be completed and submitted
# ****
# + reference: https://docs.python.org/2.7/library/xml.etree.elementtree.html
# + data source: http://www.dbis.informatik.uni-goettingen.de/Mondial
# ****

# %%
from xml.etree import ElementTree as ET

# %% [markdown]
# ## XML example
#
# + for details about tree traversal and iterators, see https://docs.python.org/2.7/library/xml.etree.elementtree.html

# %%
document_tree = ET.parse( './data/mondial_database_less.xml' )

# %%
# print names of all countries
for child in document_tree.getroot():
    print child.find('name').text
# Out:
# Albania
# Greece
# Macedonia
# Serbia
# Montenegro
# Kosovo
# Andorra

# %%
# print names of all countries and their cities
for element in document_tree.iterfind('country'):
    print '* ' + element.find('name').text + ':',
    capitals_string = ''
    for subelement in element.getiterator('city'):
        capitals_string += subelement.find('name').text + ', '
    print capitals_string[:-2]
# Out:
# * Albania: Tirana, Shkodër, Durrës, Vlorë, Elbasan, Korçë
# * Greece: Komotini, Kavala, Athina, Peiraias, Peristeri, Acharnes, Patra, Kozani, Kerkyra, Ioannina, Thessaloniki, Iraklio, Chania, Ermoupoli, Rhodes, Tripoli, Lamia, Chalkida, Larissa, Volos, Mytilini, Karyes
# * Macedonia: Skopje, Kumanovo
# * Serbia: Beograd, Novi Sad, Niš
# * Montenegro: Podgorica
# * Kosovo: Prishtine
# * Andorra: Andorra la Vella

# %% [markdown]
# ****
# ## XML exercise
#
# Using data in 'data/mondial_database.xml', the examples above, and refering to https://docs.python.org/2.7/library/xml.etree.elementtree.html, find
#
# 1. 10 countries with the lowest infant mortality rates
# 2. 10 cities with the largest population
# 3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)
# 4. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %% [markdown]
# #### 10 countries with the lowest infant mortality rates

# %%
#cElementTree process faster than ElementTree

try:
    import xml.etree.cElementTree as ET
    import pandas as pd
    import numpy as np
except ImportError:
    import xml.etree.ElementTree as ET
    import pandas as pd
    import numpy as np

# %%
document = ET.parse( './data/mondial_database.xml' )

# %%
#Create a pandas DataFrame to get top 10
country_name = ''
infant_mortality = ''
d_frame = pd.DataFrame(columns = ["country_name","infant_mortality"])
d_frame
# Out:
# Empty DataFrame
# Columns: [country_name, infant_mortality]
# Index: []

# %%
#loop over each country to get name and infant_mortality rate
#and append to dataframe
for country in document.findall('country'):
    country_name = country.find('name').text
    country_infant_mortality = country.find('infant_mortality')
    if country_infant_mortality != None: 
        country_infant_mortality = float(country_infant_mortality.text)
        d_frame.loc[len(d_frame)] = [country_name, country_infant_mortality] 

#sort by asc and show top 10
d_frame.sort_values(by = 'infant_mortality').drop_duplicates().head(10)
# Out:
#        country_name  infant_mortality
# 36           Monaco              1.81
# 90            Japan              2.13
# 109         Bermuda              2.48
# 34           Norway              2.48
# 98        Singapore              2.53
# 35           Sweden              2.60
# 8    Czech Republic              2.63
# 72        Hong Kong              2.73
# 73            Macao              3.13
# 39          Iceland              3.15

# %% [markdown]
# #### 10 cities with the largest population

# %%
city_name = ''
population = ''
df_city = pd.DataFrame(columns = ['city_name','Population'])
df_city['Population'] = df_city['Population'] .astype(float)
df_city
# Out:
# Empty DataFrame
# Columns: [city_name, Population]
# Index: []

# %%
for country in document.findall('country'):
    for city in countries.iter('city'):
        cityname = city.find('name').text
        year = int(0)
        for p in city.iterfind('population'):
            year = p.attrib['year']
            if p.attrib['year'] >= year:
                population = int(p.text)
        df_city.loc[len(df_city)] = [cityname, population] 

df_city.sort_values(by = 'Population', ascending = False).drop_duplicates().head(10)
# Out:
#      city_name  Population
# 0       Tirana    418495.0
# 2324    Durrës    113249.0
# 6327     Vlorë     79513.0
# 4264   Elbasan     78703.0
# 6919   Shkodër     77075.0
# 1235     Korçë     51152.0

# %% [markdown]
# #### 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)

# %%
country_name = ''
population = 0
ethnic_population = 0
document = ET.parse( './data/mondial_database.xml' )

df_ethnic = pd.DataFrame(columns = ['Country','Ethnic group','Population'])
df_ethnic
# Out:
# Empty DataFrame
# Columns: [Country, Ethnic group, Population]
# Index: []

# %%
for country in document.iterfind('country'):
    country_name = country.find('name').text
    year = int(0)
    population = int(0)
    ethnic_name = ''
    ethnicpopulation = ''
    
    for element in country.iterfind('population'):
        year = element.attrib['year']
        if element.attrib['year'] >= year:
            population = int(element.text)
    
    for ethnic in country.iter('ethnicgroup'):
        ethnic_name = ethnic.text
        ethnicpopulation = round(float(ethnic.attrib['percentage']) * 0.01 * int(population))

        
        if ethnic_name == None:
            ethnic_name = countryname
            ethnicpopulation = countrypopulation
        df_ethnic.loc[len(df_ethnic)] = [country_name,ethnic_name,ethnicpopulation]
df_ethnic.groupby('Ethnic group').sum().sort_values(by = 'Population', ascending = False).head(10)
# Out:
#                 Population
# Ethnic group
# Han Chinese   1.245059e+09
# Indo-Aryan    8.718156e+08
# European      4.948722e+08
# African       3.183251e+08
# Dravidian     3.027137e+08
# Mestizo       1.577344e+08
# Bengali       1.467769e+08
# Russian       1.318570e+08
# Japanese      1.265342e+08
# Malay         1.219936e+08

# %% [markdown]
# #### name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
import re
# Longest River
longest_river = ''
river_length = 0
document = ET.parse( './data/mondial_database.xml' )

df_river = pd.DataFrame(columns = ['River','Country','Length'])
df_river
# Out:
# Empty DataFrame
# Columns: [River, Country, Length]
# Index: []

# %%
for river in document.iterfind('river'):
    river_name = ''
    length = 0
    river_country_code = ''
    river_country_name = ''

    #check if name has - or not. Remove the word 'river'
    if '-' in river.attrib['id']:
        river_name = river.attrib['id'].split('-')[1]
    else:
        river_name = river.attrib['id']
    
    if river.find('source') is not None:
        #get country code and map with country name 
        river_country_code = river.find('source').get('country').split(' ')[0]
        if river.find('located') is not None:
            river_country_name = river.find('located').get('province')
            match = re.match('(-\w+ -)(\w+ -) | (-\w+ -)', river_country_name)
            print(match)
            #river_country_name = river_country_name.split(' ')[0].split('-')[1]
        print(river_name, river_country_name)
        
        #if country code is 3 characters, try to find the province name
        #and extract the middle word
        #if len(river_country_code) == 3:
        #    if river.find('located') is not None:
        #        river_country_name = river.find('located').attrib['province']
        #        river_country_name = river_country_name.split(' ')[0].split('-')[1]
        #    print(river_name, '3 charac long',river_country_name)
        #else:
        #    river_country_name = document.find(".//country[@car_code='"+river_country_code+"']")
        #    print(river_name, river_country_code)
        #    if river_country_name is not None:
        #        river_country_name.find('name').text
        
    if river.find('length') is not None:
        length = float(river.find('length').text)
    
    df_river.loc[len(df_river)] = [river_name,river_country_name,length]
df_river
# Out:
# Thjorsa
# Joekulsa_a_Fjoellum
# None
# Glomma lteil-AK-N lteil-OES-N lteil-HE-N lteil-ST-N
# None
# Lagen lteil-OP-N lteil-HE-N lteil-AK-N
# None
# Goetaaelv prov-Sweden-5
# None
# Klaraelv prov-Sweden-22
# None
# Umeaelv prov-Sweden-23
# None
# Dalaelv prov-Sweden-4 prov-Sweden-11 prov-Sweden-21 prov-Sweden-25
# None
# Vaesterdalaelv prov-Sweden-11
# None
# Oesterdalaelv prov-Sweden-11
# None
# Paatsjoki lteil-LAP-SF
# None
# Ounasjoki lteil-LAP-SF
# None
# Kemijoki lteil-LAP-SF
# None
# Oulujoki lteil-OUL-SF
# None
# Kymijoki lteil-MIK-SF lteil-KYM-SF lteil-HAE-SF
# None
# Kokemaeenjoki lteil-TUP-SF lteil-HAE-SF
# None
# Vuoksi lteil-KYM-SF lteil-KUO-SF
# None
# Themse prov-gb-6 prov-gb-7 prov-gb-8 prov-gb-9
# None
# Maas prov-Netherlands-7 prov-Netherlands-10 prov-Netherlands-12 prov-Netherlands-13
# None
# Loire prov-France-11 prov-France-25 prov-France-30 prov-France-89 prov-France-111
# None
# Garonne prov-France-5 prov-France-62 prov-France-77
# None
# Rhone prov-France-62 prov-France-111 prov-France-104
# None
# Saone prov-France-72 prov-France-25 prov-France-45 prov-France-111
# None
# Doubs prov-France-25 prov-France-45
# None
# Isere prov-France-111
# None
# Seine prov-France-25 prov-France-50 prov-France-53 prov-France-37
# None
# Marne prov-France-37 prov-France-53
# None
# Tajo prov-Spain-12 prov-Spain-10
# None
# Douro prov-Spain-9
# None
# Guadiana prov-Spain-10 prov-Spain-12 prov-Spain-2
# None
# Guadalquivir prov-Spain-2
# None
# Ebro prov-Spain-9 prov-Spain-17 prov-Spain-6 prov-Spain-16 prov-Spain-3 prov-Spain-11
# None
# Po prov-Italy-10 prov-Italy-2 prov-Italy-23 prov-Italy-41
# None
# Ticino prov-Italy-10 prov-Italy-2
# None
# Adda prov-Italy-10
# None
# Mincio prov-Italy-23
# None
# Etsch prov-Italy-20 prov-Italy-23
# None
# Tiber prov-Italy-50 prov-Italy-60 prov-Italy-68
# None
# Arno prov-Italy-50
# None
# Donau prov-Germany-2 prov-Germany-3
# None
# Breg prov-Germany-2
# None
# Brigach prov-Germany-2
# None
# Iller prov-Germany-2 prov-Germany-3
# None
# Lech prov-Germany-3
# None
# Isar prov-Germany-3
# None
# Ammer prov-Germany-3
# None
# Wurm prov-Germany-3
# None
# Inn prov-Germany-3
# None
# Alz prov-Germany-3
# None
# Salzach prov-Germany-3
# None
# Enns prov-Austria-9
# None
# March prov-Austria-10
# None
# Raab prov-Austria-2 prov-Austria-8
# None
# Waag prov-Slovakia-3 prov-Slovakia-6 prov-Slovakia-7 prov-Slovakia-8
# None
# Drau prov-Italy-20
# None
# Mur prov-Austria-9 prov-Austria-8
# None
# Theiss prov-Hungary-6 prov-Hungary-16 prov-Hungary-10 prov-Hungary-9 prov-Hungary-15 prov-Hungary-5
# None
# Save prov-BIH-1 prov-BIH-2 prov-BIH-3
# None
# Drina prov-BIH-1 prov-BIH-2
# None
# Tara prov-BIH-2
# None
# Piva prov-BIH-2
# Morava
# WesternMorava
# SouthernMorava
# None
# Olt prov-Romania-23 prov-Romania-17 prov-Romania-10 prov-Romania-35 prov-Romania-31 prov-Romania-41
# None
# Pruth prov-Romania-8 prov-Romania-26 prov-Romania-40 prov-Romania-20
# None
# Dnjestr prov-Ukraine-16 prov-Ukraine-21 prov-Ukraine-10 prov-Ukraine-4 prov-Ukraine-20 prov-Ukraine-7 prov-Ukraine-14
# None
# Weser prov-Germany-6 prov-Germany-8 prov-Germany-10 prov-Germany-11
# None
# Aller prov-Germany-10
# None
# Leine prov-Germany-10 prov-Germany-17
# None
# Werra prov-Germany-8 prov-Germany-10 prov-Germany-17
# None
# Fulda prov-Germany-8
# None
# Elbe prov-Germany-5 prov-Germany-7 prov-Germany-9 prov-Germany-10 prov-Germany-14 prov-Germany-15 prov-Germany-16
# None
# Moldau prov-Czech-1 prov-Czech-2 prov-Czech-12
# None
# Rhein prov-Germany-2 prov-Germany-8 prov-Germany-11 prov-Germany-12
# None
# Main prov-Germany-8 prov-Germany-3
# None
# Mosel prov-Germany-12 prov-Germany-13
# None
# Saar prov-Germany-12 prov-Germany-13
# None
# Neckar prov-Germany-2
# None
# Aare prov-Switzerland-2 prov-Switzerland-7 prov-Switzerland-20
# None
# Reuss prov-Switzerland-2 prov-Switzerland-13 prov-Switzerland-23
# None
# Limmat prov-Switzerland-2 prov-Switzerland-27
# None
# Oder prov-Germany-9 prov-Germany-5 prov-Germany-14
# None
# Weichsel prov-PL-11 prov-PL-2 prov-PL-7 prov-PL-13 prov-PL-3 prov-PL-6 prov-PL-9 prov-PL-12
# None
# Narew prov-PL-7 prov-PL-10
# None
# WesternBug prov-PL-7 prov-PL-10 prov-PL-3
# Moraca
# Buna
# Drin
# Weisser_Drin
# Schwarzer_Drin
# None
# Jordan prov-Israel-5
# None
# Kura prov-Turkey-77 prov-Turkey-42
# None
# SchattAlArab prov-Iraq-5
# None
# Tigris prov-Turkey-13 prov-Turkey-25 prov-Turkey-63 prov-Turkey-53 prov-Turkey-65
# None
# Euphrat prov-Iraq-2 prov-Iraq-3 prov-Iraq-8 prov-Iraq-13 prov-Iraq-11 prov-Iraq-10 prov-Iraq-6 prov-Iraq-5
# None
# Murat prov-Turkey-27 prov-Turkey-16 prov-Turkey-55 prov-Turkey-5
# None
# Karasu prov-Turkey-28 prov-Turkey-29
# None
# Karun prov-Iran-5 prov-Iran-7 prov-Iran-8 prov-Iran-16
# None
# Noerdliche_Dwina prov-Russia-5 prov-Russia-7
# None
# Suchona prov-Russia-7
# None
# Petschora prov-Russia-4 prov-Russia-5
# None
# Newa prov-Russia-11
# None
# Swir prov-Russia-11
# None
# Narva prov-Russia-13
# None
# Westliche_Dwina prov-Russia-23
# None
# Dnister prov-Ukraine-14 prov-Ukraine-7 prov-Ukraine-20 prov-Ukraine-10 prov-Ukraine-4 prov-Ukraine-21 prov-Ukraine-16
# None
# Dnepr prov-Ukraine-2 prov-Ukraine-3 prov-Ukraine-5 prov-Ukraine-9 prov-Ukraine-11 prov-Ukraine-12 prov-Ukraine-17 prov-Ukraine-24 prov-Ukraine-28
# None
# Prypjat prov-Ukraine-11 prov-Ukraine-22
# None
# Don prov-Russia-25 prov-Russia-33 prov-Russia-35 prov-Russia-40 prov-Russia-45
# None
# Wolga prov-Russia-16 prov-Russia-18 prov-Russia-24 prov-Russia-26 prov-Russia-27 prov-Russia-29 prov-Russia-31 prov-Russia-39 prov-Russia-40 prov-Russia-41 prov-Russia-42 prov-Russia-43 prov-Russia-44
# None
# Oka prov-Russia-15 prov-Russia-17 prov-Russia-20 prov-Russia-21 prov-Russia-22 prov-Russia-25 prov-Russia-31
# None
# Kama prov-Russia-47 prov-Russia-30 prov-Russia-49 prov-Russia-46 prov-Russia-38
# None
# Ural prov-Russia-46 prov-Russia-48 prov-Russia-63
# None
# Ob prov-Russia-65 prov-Russia-67 prov-Russia-69 prov-Russia-70 prov-Russia-91 prov-Russia-92
# None
# Irtysch prov-Russia-68 prov-Russia-70 prov-Russia-91
# None
# Tobol prov-Russia-48 prov-Russia-61 prov-Russia-70
# None
# Ischim prov-Russia-68 prov-Russia-70
# None
# Katun prov-Russia-65 prov-Russia-64
# None
# Jenissej prov-Russia-75 prov-Russia-74 prov-Russia-73
# None
# Angara prov-Russia-75 prov-Russia-77 prov-Russia-72
# None
# Selenge prov-Russia-72
# None
# Chatanga prov-Russia-75
# None
# Lena prov-Russia-77 prov-Russia-81
# None
# Amur prov-Russia-79 prov-Russia-82 prov-Russia-85 prov-Russia-86
# None
# Schilka prov-Russia-79
# None
# Argun prov-Russia-79
# None
# Kolyma prov-Russia-89 prov-Russia-81
# None
# Syrdarja prov-Kazakhstan-9 prov-Kazakhstan-13 prov-Kazakhstan-23
# None
# Naryn prov-Uzbekistan-13
# None
# Amudarja prov-Tajikistan-4
# None
# Pjandsh prov-Tajikistan-4 prov-Tajikistan-6
# None
# Bartang prov-Tajikistan-6
# None
# Murgab prov-Tajikistan-6
# None
# Ili prov-China-28
# None
# Tarim prov-China-28 prov-China-29
# None
# Hwangho prov-China-4 prov-China-10 prov-China-17 prov-China-18 prov-China-19 prov-China-26 prov-China-27
# None
# Jangtse prov-China-2 prov-China-11 prov-China-12 prov-China-13 prov-China-14 prov-China-17 prov-China-21 prov-China-22 prov-China-29 prov-China-32 prov-China-34
# None
# Mekong prov-China-22 prov-China-29
# None
# Saluen prov-China-22 prov-China-29
# None
# Irawaddy prov-China-22 prov-China-29
# None
# Ganges prov-India-26 prov-India-25 prov-India-5 prov-India-36 prov-India-38
# None
# Brahmaputra prov-China-29
# None
# Indus prov-China-29
# None
# Asahan prov-RI-2
# None
# Yukon prov-Canada-13
# None
# Mackenzie prov-Canada-7
# None
# NelsonRiver prov-Canada-4
# None
# SaskatchewanRiver prov-Canada-2 prov-Canada-4 prov-Canada-12
# None
# StLorenzstrom prov-Canada-11
# None
# NiagaraRiver prov-Canada-9
# None
# DetroitRiver prov-Canada-9
# None
# Saint prov-Canada-9
# None
# Straits prov-United-States-23
# None
# Manicouagan prov-Canada-11
# None
# Richelieu prov-Canada-11
# None
# MerrimackRiver prov-United-States-22 prov-United-States-30
# None
# Connecticut_River prov-United-States-8 prov-United-States-22 prov-United-States-30 prov-United-States-46
# None
# Hudson_River prov-United-States-33 prov-United-States-31
# None
# Mississippi_River prov-United-States-5 prov-United-States-14 prov-United-States-16 prov-United-States-18 prov-United-States-19 prov-United-States-24 prov-United-States-25 prov-United-States-26 prov-United-States-43 prov-United-States-50
# None
# Missouri_River prov-United-States-16 prov-United-States-17 prov-United-States-26 prov-United-States-27 prov-United-States-28 prov-United-States-35 prov-United-States-42
# None
# Arkansas_River prov-United-States-5 prov-United-States-7 prov-United-States-17 prov-United-States-37
# None
# Ohio prov-United-States-39 prov-United-States-36 prov-United-States-15 prov-United-States-14 prov-United-States-18 prov-United-States-49
# None
# Allegheny prov-United-States-39 prov-United-States-33
# None
# TennesseeRiver prov-United-States-2 prov-United-States-18 prov-United-States-43 prov-United-States-34
# None
# Columbia_River prov-Canada-3
# None
# TruckeeRiver prov-United-States-6 prov-United-States-29
# None
# Colorado_River prov-Mexico-3 prov-Mexico-26
# None
# RioGrande prov-Mexico-7 prov-Mexico-8 prov-Mexico-19 prov-Mexico-28
# None
# RioLerma prov-Mexico-22 prov-Mexico-16 prov-Mexico-11 prov-Mexico-18 prov-Mexico-14 prov-Mexico-15
# None
# RioSanJuan prov-Costa-Rica-3 prov-Costa-Rica-5 prov-Costa-Rica-8
# None
# Desaguadero prov-BOL-1 prov-BOL-2
# None
# RioMagdalena prov-Colombia-5 prov-Colombia-6 prov-Colombia-20 prov-Colombia-3 prov-Colombia-23 prov-Colombia-29 prov-Colombia-7 prov-Colombia-8 prov-Colombia-31 prov-Colombia-19
# None
# Orinoco prov-Venezuela-2 prov-Venezuela-3 prov-Venezuela-4 prov-Venezuela-7 prov-Venezuela-10 prov-Venezuela-12 prov-Venezuela-16
# None
# Amazonas prov-Colombia-2
# None
# RioNegro prov-Colombia-16
# None
# RioMadeira prov-Brazil-5 prov-Brazil-22
# None
# RioMamore prov-BOL-5 prov-BOL-8
# None
# Tocantins prov-Brazil-10 prov-Brazil-14 prov-Brazil-27 prov-Brazil-9
# None
# RioSaoFrancisco prov-Brazil-13 prov-Brazil-6 prov-Brazil-26 prov-Brazil-3 prov-Brazil-17
# None
# Parana prov-Argentina-2 prov-Argentina-4 prov-Argentina-7 prov-Argentina-8 prov-Argentina-14 prov-Argentina-21 prov-Argentina-26
# None
# Paraguay prov-Argentina-9 prov-Argentina-4
# None
# Uruguay prov-Argentina-14 prov-Argentina-8 prov-Argentina-7
# None
# Gambia prov-Senegal-9 prov-Senegal-6 prov-Senegal-14
# None
# Senegal prov-Senegal-9 prov-Senegal-8 prov-Senegal-12
# None
# Volta prov-GH-2 prov-GH-4 prov-GH-5 prov-GH-6 prov-GH-8 prov-GH-9
# None
# Niger prov-RMM-1 prov-RMM-2 prov-RMM-3 prov-RMM-5 prov-RMM-6 prov-RMM-7 prov-RMM-9
# None
# Bani prov-CI-10 prov-CI-14
# None
# Benue prov-Cameroon-7
# None
# Schari prov-Cameroon-5
# Nil
# None
# Atbara prov-ETH-3
# None
# Blauer_Nil prov-ETH-3 prov-ETH-4 prov-ETH-8
# Weisser_Nil
# Sobat
# None
# Pibor prov-ETH-6
# None
# Baro prov-ETH-6 prov-ETH-8
# Bahr_el
# Bahr_el
# None
# Semliki prov-Zaire-5 prov-Zaire-11
# ViktoriaNil
# None
# Akagera prov-Tanzania-19
# None
# Jubba prov-ETH-9 prov-ETH-8
# None
# Shabelle prov-ETH-9
# None
# Sanaga prov-Cameroon-3 prov-Cameroon-4 prov-Cameroon-6
# None
# Zaire prov-Zaire-2 prov-Zaire-3 prov-Zaire-4 prov-Zaire-5 prov-Zaire-10
# None
# Sanga prov-Cameroon-4
# None
# Ubangi prov-Zaire-4
# None
# Bomu prov-Zaire-5
# None
# Uelle prov-Zaire-4 prov-Zaire-5
# None
# Kwa prov-Zaire-2
# None
# Fimi prov-Zaire-2
# None
# Lukenie prov-Zaire-2 prov-Zaire-6 prov-Zaire-7
# None
# Kasai prov-Angola-9 prov-Angola-10 prov-Angola-14
# None
# Kuango prov-Angola-4 prov-Angola-8 prov-Angola-9 prov-Angola-10
# None
# Kwilu prov-Angola-13 prov-Angola-14 prov-Angola-15
# None
# Ruki prov-Zaire-4
# None
# Busira prov-Zaire-4
# None
# Tshuapa prov-Zaire-4 prov-Zaire-7
# None
# Lulua prov-Zaire-6 prov-Zaire-9
# None
# Lomami prov-Zaire-5 prov-Zaire-7 prov-Zaire-13 prov-Zaire-9
# None
# Aruwimi prov-Zaire-5
# None
# Lualaba prov-Zaire-9 prov-Zaire-13 prov-Zaire-5
# None
# Lukuga prov-Zaire-9
# None
# Ruzizi prov-Zaire-12
# None
# Luvua prov-Zaire-9
# None
# Luapula prov-Zaire-9
# None
# Sambesi prov-Angola-14
# None
# Shire prov-Mozambique-10 prov-Mozambique-11
# None
# Okavango prov-Angola-13
# None
# Limpopo prov-South-Africa-4 prov-South-Africa-8
# None
# Oranje prov-South-Africa-3 prov-South-Africa-7
# None
# Vaal prov-South-Africa-3 prov-South-Africa-9 prov-South-Africa-6 prov-South-Africa-7
# None
# MurrayRiver prov-Australia-2 prov-Australia-5 prov-Australia-7
# None
# DarlingRiver prov-Australia-2 prov-Australia-4
# None
# MurrumbidgeeRiver prov-Australia-9 prov-Australia-2
# None
# Eucumbene prov-Australia-2
# None
# SnowyRiver prov-Australia-2 prov-Australia-7
#                     River                                            Country  \
# 0                 Thjorsa
# 1     Joekulsa_a_Fjoellum
# 2                  Glomma       lteil-AK-N lteil-OES-N lteil-HE-N lteil-ST-N
# 3                   Lagen                   lteil-OP-N lteil-HE-N lteil-AK-N
# 4               Goetaaelv                                      prov-Sweden-5
# 5                Klaraelv                                     prov-Sweden-22
# 6                 Umeaelv                                     prov-Sweden-23
# 7                 Dalaelv  prov-Sweden-4 prov-Sweden-11 prov-Sweden-21 pr...
# 8          Vaesterdalaelv                                     prov-Sweden-11
# 9           Oesterdalaelv                                     prov-Sweden-11
# 10              Paatsjoki                                       lteil-LAP-SF
# 11              Ounasjoki                                       lteil-LAP-SF
# 12               Kemijoki                                       lteil-LAP-SF
# 13               Oulujoki                                       lteil-OUL-SF
# 14               Kymijoki             lteil-MIK-SF lteil-KYM-SF lteil-HAE-SF
# 15          Kokemaeenjoki                          lteil-TUP-SF lteil-HAE-SF
# 16                 Vuoksi                          lteil-KYM-SF lteil-KUO-SF
# 17                 Themse            prov-gb-6 prov-gb-7 prov-gb-8 prov-gb-9
# 18                   Maas  prov-Netherlands-7 prov-Netherlands-10 prov-Ne...
# 19                  Loire  prov-France-11 prov-France-25 prov-France-30 p...
# 20                Garonne        prov-France-5 prov-France-62 prov-France-77
# 21                  Rhone     prov-France-62 prov-France-111 prov-France-104
# 22                  Saone  prov-France-72 prov-France-25 prov-France-45 p...
# 23                  Doubs                      prov-France-25 prov-France-45
# 24                  Isere                                    prov-France-111
# 25                  Seine  prov-France-25 prov-France-50 prov-France-53 p...
# 26                  Marne                      prov-France-37 prov-France-53
# 27                   Tajo                        prov-Spain-12 prov-Spain-10
# 28                  Douro                                       prov-Spain-9
# 29               Guadiana           prov-Spain-10 prov-Spain-12 prov-Spain-2
# ...                   ...                                                ...
# 1398                 Bomu                                       prov-Zaire-5
# 1399                Uelle                          prov-Zaire-4 prov-Zaire-5
# 1400                  Kwa                                       prov-Zaire-2
# 1401                 Fimi                                       prov-Zaire-2
# 1402              Lukenie             prov-Zaire-2 prov-Zaire-6 prov-Zaire-7
# 1403                Kasai        prov-Angola-9 prov-Angola-10 prov-Angola-14
# 1404               Kuango  prov-Angola-4 prov-Angola-8 prov-Angola-9 prov...
# 1405                Kwilu       prov-Angola-13 prov-Angola-14 prov-Angola-15
# 1406                 Ruki                                       prov-Zaire-4
# 1407               Busira                                       prov-Zaire-4
# 1408              Tshuapa                          prov-Zaire-4 prov-Zaire-7
# 1409                Lulua                          prov-Zaire-6 prov-Zaire-9
# 1410               Lomami  prov-Zaire-5 prov-Zaire-7 prov-Zaire-13 prov-Z...
# 1411              Aruwimi                                       prov-Zaire-5
# 1412              Lualaba            prov-Zaire-9 prov-Zaire-13 prov-Zaire-5
# 1413               Lukuga                                       prov-Zaire-9
# 1414               Ruzizi                                      prov-Zaire-12
# 1415                Luvua                                       prov-Zaire-9
# 1416              Luapula                                       prov-Zaire-9
# 1417              Sambesi                                     prov-Angola-14
# 1418                Shire              prov-Mozambique-10 prov-Mozambique-11
# 1419             Okavango                                     prov-Angola-13
# 1420              Limpopo            prov-South-Africa-4 prov-South-Africa-8
# 1421               Oranje            prov-South-Africa-3 prov-South-Africa-7
# 1422                 Vaal  prov-South-Africa-3 prov-South-Africa-9 prov-S...
# 1423          MurrayRiver  prov-Australia-2 prov-Australia-5 prov-Austral...
# 1424         DarlingRiver                  prov-Australia-2 prov-Australia-4
# 1425    MurrumbidgeeRiver                  prov-Australia-9 prov-Australia-2
# 1426            Eucumbene                                   prov-Australia-2
# 1427           SnowyRiver                  prov-Australia-2 prov-Australia-7
#
#       Length
# 0      230.0
# 1      206.0
# 2      604.0
# 3      322.0
# 4       93.0
# 5      460.0
# 6      470.0
# 7      520.0
# 8      320.0
# 9      241.0
# 10     145.0
# 11     300.0
# 12     550.0
# 13     107.0
# 14     203.0
# 15     121.0
# 16     162.0
# 17     346.0
# 18     925.0
# 19    1013.0
# 20     647.0
# 21     812.0
# 22     480.0
# 23     453.0
# 24     290.0
# 25     776.0
# 26     514.0
# 27    1007.0
# 28     897.0
# 29     742.0
# ...      ...
# 1398   280.0
# 1399  1130.0
# 1400   100.0
# 1401   200.0
# 1402   900.0
# 1403  1983.0
# 1404  1100.0
# 1405   970.0
# 1406   130.0
# 1407   830.0
# 1408  1300.0
# 1409   970.0
# 1410  1450.0
# 1411  1287.0
# 1412     0.0
# 1413   350.0
# 1414   104.0
# 1415   350.0
# 1416   300.0
# 1417  2574.0
# 1418   402.0
# 1419  1700.0
# 1420  1750.0
# 1421  2160.0
# 1422  1251.0
# 1423  2589.0
# 1424  2739.0
# 1425  1579.0
# 1426    83.0
# 1427   403.0
#
# [1428 rows x 3 columns]
